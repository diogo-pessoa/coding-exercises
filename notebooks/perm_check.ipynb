# %% [markdown]
# A non-empty array A consisting of N integers is given.
#
# A permutation is a sequence containing each element from 1 to N once, and only once.
#
# For example, array A such that:
#
#     A[0] = 4
#     A[1] = 1
#     A[2] = 3
#     A[3] = 2
# is a permutation, but array A such that:
#
#     A[0] = 4
#     A[1] = 1
#     A[2] = 3
# is not a permutation, because value 2 is missing.
#
# The goal is to check whether array A is a permutation.
#
# Write a function:
#
# def solution(A)
#
# that, given an array A, returns 1 if array A is a permutation and 0 if it is not.
#
# For example, given array A such that:
#
#     A[0] = 4
#     A[1] = 1
#     A[2] = 3
#     A[3] = 2
# the function should return 1.
#
# Given array A such that:
#
#     A[0] = 4
#     A[1] = 1
#     A[2] = 3
# the function should return 0.
#
# Write an efficient algorithm for the following assumptions:
#
# N is an integer within the range [1..100,000];
# each element of array A is an integer within the range [1..1,000,000,000].

# %%
import os
import sys

# Loading local helper modules
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import random


A = [4, 1, 3, 2]
B = [4, 1, 3]
perms = [B, A]
for i in range(1, 30):
    X = random.randint(1, 1000000)
    values = random.sample(range(1, X + 1), X)
    perms.append(values)

# %%
def count_time(func, *args):
    start = time.time()
    func(*args)
    end = time.time()
    duration = format(end - start, '.7f')
    return duration

# %%
import time
from coded_solutions import perm_check

time_totals = [[], []]
solution = [perm_check.solution_improvement, perm_check.solution_improvement_l]
for i, v in enumerate(perms):
    for i, s in enumerate(solution):
        time_totals[i].append(count_time(s, v))

# %%
import numpy as np

time_totals_imp = np.array(time_totals[0])
time_totals_l = np.array(time_totals[1])

# %%
import matplotlib.pyplot as plt

time_totals = np.array(time_totals, dtype=float)
plt.plot(time_totals_imp, label='imp')
plt.plot(time_totals_l, label='l')
plt.xlabel('Permutation')
plt.ylabel('Time')
plt.legend()
plt.show()
