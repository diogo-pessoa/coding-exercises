# %%
times_table = [
    [x * y
     for x in range(0,13,)]
    for y in range(0,13)
]
inverted_times_table = times_table[::-1]

# %%
x_axis = range(0, len(combined_sequence) + 1)
x_axis = np.array(x_axis)
x_axis.shape
# Out:
# (13,)

# %%
combined_sequence_np = np.array(times_table[:-1] + inverted_times_table)

# %%
import matplotlib.pyplot as plt
plt.plot(combined_sequence_np)
plt.legend([f'{i} x' for i in range(0, 13)])
plt.show()
